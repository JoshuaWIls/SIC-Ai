# %%
import numpy as np
x=np.linspace(-1,5,200)
y=np.linspace(-1,5,200)
z=2*x+5*y-3

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot(x, y, z, 'green')

# %%
z=x-y
ax = plt.axes(projection='3d')
ax.plot(x, y, z, 'green')

# %%
z=2*x-y+4
ax = plt.axes(projection='3d')
ax.plot(x, y, z, 'green')

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.view_init(elev=10,azim=60,roll=360)
ax.plot(x,y,z)

# %%
z=x**2+y**2
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='Greens') 
plt.show()

# %%
z=x**2+4*y**2
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='Greens') 
plt.show()

# %%
x = np.linspace(-6, 6, 200)
y = np.linspace(-6, 6, 200)
x, y = np.meshgrid(x, y)

# %%
z=(x-3)**2/2**2+(y-1)**2/4**2
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='Greens') 
plt.show()

# %%
z=x**2-y**2
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='Greens') 
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='Greens') 
plt.show()

# %%
x = np.linspace(-6, 6, 200)
y = np.linspace(-6, 6, 200)
x, y = np.meshgrid(x, y)
z = x * y
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='Greens') 
plt.show()

# %%
x = np.linspace(-10, 10, 200)
y = np.linspace(-10, 10, 200)
x, y = np.meshgrid(x, y)
z=10-x**2--y**2
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='Greens') 
plt.show()

# %%
z=x*np.sin(y)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='Greens') 
plt.show()

# %%
z=2*np.sqrt(x)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='Greens') 
plt.show()
# Out:
# C:\Users\student\AppData\Local\Temp\ipykernel_12004\1710392617.py:1: RuntimeWarning: invalid value encountered in sqrt
#   z=2*np.sqrt(x)

# %%
import pandas as pd
import numpy as np
x = [3.4, 3.2, 3.1, 3.0, 3.4, 3.2, 3.8, 2.9, 2.8]
g = [0, 0, 1, 1, 0, 1, 0, 1, 0]
df = pd.DataFrame({'x': x, 'g': g})
m = -1
c = 3
df['y'] = m * df['x'] + c
df['predicted'] = (1 / (1 + np.exp(-df['y'])) >= 0.5).astype(int)
df = df[['x', 'g', 'predicted']]
print(df)
# Out:
#      x  g  predicted
# 0  3.4  0          0
# 1  3.2  0          0
# 2  3.1  1          0
# 3  3.0  1          1
# 4  3.4  0          0
# 5  3.2  1          0
# 6  3.8  0          0
# 7  2.9  1          1
# 8  2.8  0          1

# %%
import pandas as pd
import numpy as np
x = [3.4, 3.2, 3.1, 3.0, 3.4, 3.2, 3.8, 2.9, 2.8]
g = [0, 0, 1, 1, 0, 1, 0, 1, 0]
df = pd.DataFrame({'x': x, 'g': g})
m = -0.5
c = 2.8
df['y'] = m * df['x'] + c
df['predicted'] = (np.tanh(df['y']) >= 0).astype(int)
df = df[['x', 'g', 'predicted']]
print(df)
# Out:
#      x  g  predicted
# 0  3.4  0          1
# 1  3.2  0          1
# 2  3.1  1          1
# 3  3.0  1          1
# 4  3.4  0          1
# 5  3.2  1          1
# 6  3.8  0          1
# 7  2.9  1          1
# 8  2.8  0          1

# %%
import pandas as pd
import numpy as np
x = [3.4, 3.2, 3.1, 3.0, 3.4, 3.2, 3.8, 2.9, 2.8]
g = [0, 0, 1, 1, 0, 1, 0, 1, 0]
df = pd.DataFrame({'x': x, 'g': g})
m = -1.3
c = 4.5
df['y'] = m * df['x'] + c
df['predicted'] = (np.tanh(df['y']) >= 0).astype(int)
df = df[['x', 'g', 'predicted']]
print(df)
# Out:
#      x  g  predicted
# 0  3.4  0          1
# 1  3.2  0          1
# 2  3.1  1          1
# 3  3.0  1          1
# 4  3.4  0          1
# 5  3.2  1          1
# 6  3.8  0          0
# 7  2.9  1          1
# 8  2.8  0          1

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
data = load_iris()
X = data.data
y = data.target
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
pca = PCA(n_components=2)  
X_pca = pca.fit_transform(X_scaled)
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA on Iris Dataset')
plt.legend(*scatter.legend_elements(), title="Classes")
plt.grid(True)
plt.show()
print("Explained variance ratio:", pca.explained_variance_ratio_)
# Out:
# Explained variance ratio: [0.72962445 0.22850762]
